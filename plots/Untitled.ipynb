# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline
style.use('ggplot')
# Out:
# ['seaborn-bright',
#  'Solarize_Light2',
#  'seaborn-notebook',
#  'seaborn-ticks',
#  'grayscale',
#  'seaborn-muted',
#  'seaborn-paper',
#  '_classic_test',
#  'seaborn',
#  'seaborn-darkgrid',
#  'seaborn-talk',
#  'bmh',
#  'seaborn-colorblind',
#  'seaborn-poster',
#  'fast',
#  'seaborn-pastel',
#  'seaborn-dark-palette',
#  'seaborn-whitegrid',
#  'ggplot',
#  'seaborn-deep',
#  'seaborn-dark',
#  'dark_background',
#  'tableau-colorblind10',
#  'classic',
#  'seaborn-white',
#  'fivethirtyeight']

# %% [markdown]
# # Flows

# %%
df = pd.read_csv('t1results.csv')
df.head()
# Out:
#    k   flow   paths   time
# 0  1      2       2   1744
# 1  1      2       2    692
# 2  1      2       2    621
# 3  1      2       2    559
# 4  1      2       2    562

# %%
flows = df[['k', ' flow']].groupby('k').mean()[' flow']
paths = df[['k', ' paths']].groupby('k').mean()[' paths']
time = df[['k', ' time']].groupby('k').mean()[' time']

# %%
scale = [2**(k+1) for k in range(16)]
plt.plot(scale, flows)
plt.title('calculated flow')
plt.xlabel('graph size')
plt.show()
plt.plot(scale, paths)
plt.title('number of calculated paths')
plt.xlabel('graph size')
plt.show()
plt.plot(scale, time)
plt.title('execution time')
plt.xlabel('graph size')
plt.show()

# %% [markdown]
# # Matches

# %%
df = pd.read_csv('t2results.csv')
df.head()
# Out:
#    k   i   matches   time
# 0  3   1         5   3112
# 1  3   1         7   1842
# 2  3   1         4   2387
# 3  3   1         6   1969
# 4  3   1         5   2049

# %%
for k in range(3,11):
    kdf = df[df['k'] == k]
    kdf[[' i', ' matches']].groupby(' i').mean().plot(title='k={}'.format(k))

# %%
for i in range(1,11):
    cur_df = df[df[' i'] == i]
    cur_df[['k', ' time']].groupby('k').mean().rename(columns = {' time':'time (ns)'}).plot(title='i={}'.format(i), kind='area')
